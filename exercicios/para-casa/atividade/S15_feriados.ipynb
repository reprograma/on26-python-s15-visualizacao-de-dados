# %% [markdown]
# # FERIADOS DE 2023, AO REDOR DO MUNDO
# Decidi criar vizualizações dos feriados de 2023 em 8 países diferentes, sendo eles:
#     - Brasil
#     - Canadá
#     - Japão
#     - Coreia do Sul
#     - Portugal
#     - Reino Unido
#     - China
#     - Estados Unidos da América

# %% [markdown]
# Tive que fazer algumas mudanças no dataset dos Estados Unidos, pode ver as mudanças no arquivo 'mudancas.ipynb'
#
# Fiz também um novo arquivo csv para juntar os 8 países que escolhi para fazer essas vizualizações.

# %% [markdown]
# #### Link do projeto:
# https://public.tableau.com/app/profile/thaysa.lima/viz/S15_Feriadosem2023/Painel2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
