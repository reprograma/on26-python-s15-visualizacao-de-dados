# %% [markdown]
# # Atividade semana 15

# %%
import pandas as pd

# %%
df = pd.read_csv("base_exercicio_s14_olist.csv")
df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 114854  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 114855  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 114856  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 114857  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 114858  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status reference_month  order_item_id  \
# ...

# %% [markdown]
# Utilizei uma base tratada na atividade da semana 14.

# %% [markdown]
# ### A 1º visualização mostra as vendas de 11 cidades da região metropolitana de Pernambuco.
# Recife com um número 4x maior que a cidade seguinte Jaboatão dos Guararapes, como podemos ver no gráfico a baixo.
#
# ![](imagens/grafico1.jpg)
#
#
# ### Na 2ª visualização temos um ranking de vendas por ano em 3 cidades (Recife, Olinda e Paulista) de Pernambuco.
# Neste gráfico podemos perceber que as vendas na capital começou em 2016, poucas vendas em relação aos anos seguintes, mas nas outras cidades só começaram no ano seguinte.
#
# ![](imagens/grafico2.jpg)
#
#
# ### Na 3ª visualização vemos o tipo de pagamento mais utilizado nas compras nas mesmas 3 cidades.
# O tipo de pagamento mais utilizado é o cartão de crédito nas 3 cidades.
#
# ![](imagens/grafico3.jpg)
#
#
# ### A 4ª visualização mostra a quantidade de avaliações após as compras(estrelas no app/site).
# Percebemos que o serviço é pouco avaliado de acordo a quantidade de vendas, embora o Recife tenha vendido 451 vezes em 2016, a empresa só teve 16 avaliações sobre suas vendas.
#
# ![](imagens/grafico4.jpg)
#
#
#
# ## Dashboard publicado.
#
# ![](imagens/Painel%201.png)
