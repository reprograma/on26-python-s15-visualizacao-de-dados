# %% [markdown]
# # exercitando no tableau visualizações com dados de Minas Gerais

# %% [markdown]
# ![dashboard.png](attachment:dashboard.png)

# %% [markdown]
# https://public.tableau.com/views/semana15-reprogramaolist/Painel1?:language=pt-BR&:display_count=n&:origin=viz_share_link
