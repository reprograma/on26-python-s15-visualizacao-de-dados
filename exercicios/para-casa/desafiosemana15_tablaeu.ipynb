# %%
from IPython.display import Image

print = 'dashboard.png'

Image(filename=print)

# %% [markdown]
# Link para dashboard para resolução atividade da semana 15:
#
# https://public.tableau.com/authoring/DESAFIOSEMANA15/Painel1#3
