# %% [markdown]
# # Desafio Semana 15

# %% [markdown]
# ## Base de Informações dos Dados
#
# O DataSet Base de Informação que utilizo é  o da Netflix, já utilizado em algumas aulas anteriores
#
# O DataSet Base tem a seguinte composição:

# %%
import pandas as pd

# %%
#Exibição do DataSet Base
df = pd.read_csv("netflix.csv")
df
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %% [markdown]
# Sobre essa base de dados foram extraídas 6 formas de análise de gráficos
# essas visualizações podem ser encontradas dentro do meu portifólio do Tableu.
# O link de Acesso a essa Publicação do Dashboard é:
#
# - Dashboard Parte 1
#
# https://public.tableau.com/views/Painelanaliticonetflixpt1/Painel1?:language=pt-BR&:display_count=n&:origin=viz_share_link
#
# - Dashboard Parte 2
#
# https://public.tableau.com/views/PainelanaliticoNetflixPt2/Painel2?:language=pt-BR&:display_count=n&:origin=viz_share_link
#
#
#
#
#
# Caso não seja possível acessar o link, você também consegue acompanhar aqui embaixo neste mesmo arquivo.

# %% [markdown]
# ## Visualizações
#
# Dashboard trazendo as 6 visualizações pedidas com Base de dados da Netflix
#
# - Parte 1
#
# ![ Print DashBoard Parte 1](dashboardpt1.png)
#
# - Parte 2
#
# ![ Print DashBoard Parte 2](dashboardpt2.png)
