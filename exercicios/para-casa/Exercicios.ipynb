# %%
# https://public.tableau.com/app/profile/dayani.rosa/viz/Base-semana15/col1
# https://public.tableau.com/app/profile/dayani.rosa/viz/painel_17014556554120/Painel1
# https://public.tableau.com/app/profile/dayani.rosa/viz/coluna3/col3
# https://public.tableau.com/app/profile/dayani.rosa/viz/coluna2/col2
# https://public.tableau.com/views/coluna4/col5?:language=pt-BR&:display_count=n&:origin=viz_share_link
#

# %% [markdown]
# #prints
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
