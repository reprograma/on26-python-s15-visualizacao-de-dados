# %% [markdown]
# ***<div style="background-color:blue; padding:10px;text-align:center"><span style="color:yellow; font-size:3em">ATIVIDADE SEMANA 15***<img src="https://pa1.aminoapps.com/7094/61a0f7dd0a3db2608cfdc46140deff3f544307f9r1-256-256_00.gif" alt="Super Mario Bros" width="100"/></span></div>

# %% [markdown]
# ***<div style="background-color:blue; padding:10px;text-align:center"><span style="color:yellow; font-size:2em">Link da atividade: https://public.tableau.com/views/dani_negrao_S15/Painel1?:language=pt-BR&:display_count=n&:origin=viz_share_link***<img src="https://pa1.aminoapps.com/7094/61a0f7dd0a3db2608cfdc46140deff3f544307f9r1-256-256_00.gif" alt="Super Mario Bros" width="60"/></span></div>

# %%
from IPython.display import Image

imagem_s15 = 'semana_15.png'

Image(filename=imagem_s15)

# %% [markdown]
# ***<div style="background-color:blue; padding:10px;text-align:center"><span style="color:yellow; font-size:1,5em">Deborah,<br> Quero agradecer imensamente pelas últimas semanas juntas. Tive algumas dificuldades na atividade, especialmente na organização dos gráficos no painel, mas cada desafio foi valioso. Sua didática é incrível, simples, clara e objetiva. Foi um prazer imenso estar sob sua orientação. Você é uma profissional excepcional, e desejo muito sucesso em sua jornada. Espero que hoje seja um "até logo", pessoas como você deve ficar sempre por perto. <br>Obrigada, por tudo!***

# %% [markdown]
# <img src="https://media.tenor.com/5MiYDu_08kIAAAAC/videogames-mario.gif" alt="Super Mario Bros" width="500"/></span></div>
